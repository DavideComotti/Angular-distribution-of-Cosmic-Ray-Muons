# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install uproot
# !pip install awkward-pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.8/393.8 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 919.6/919.6 kB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 656.7/656.7 kB 43.6 MB/s eta 0:00:00
# ...

# %%
import uproot
import pandas as pd

# %%
file = uproot.open("/content/drive/MyDrive/Laurea Triennale 94 110/Terzo anno/Tirocinio/Python/Mixed data- Legnaro/256-357-358/mixed_data_256.root")

tree = file["TFTree;7"]

df = tree.arrays(library="pd")
print(df.head())
# Out:
#    evNumber  matchCode       TT          hasMT                    t0_in  \
# 0         0          6   9160.0  [False False]          [7344.5 7840.5]
# 1         1          6  31304.0  [False False]        [28715.5 29055.0]
# 2         2          8  -9999.0  [False False]        [-9999.0 19083.0]
# 3         3          6  47160.0  [False False]        [45245.0 44776.0]
# 4         4         14  60528.0   [False True]  [58875.1015625 58861.5]
#
#                      t_low                    t_upp  \
# 0        [-9999.0 -9999.0]        [-9999.0 -9999.0]
# 1        [-9999.0 -9999.0]        [-9999.0 -9999.0]
# 2        [-9999.0 19083.0]        [-9999.0 19446.0]
# 3        [-9999.0 -9999.0]        [-9999.0 -9999.0]
# 4  [58825.1015625 58811.5]  [60325.1015625 60311.5]
#
#                         t0_TF         npt_TF                            m_TF  \
# 0  [-9999.0 7788.07666015625]      [-9999 9]     [-9999.0 1.252439260482788]
# ...

# %%
qtf_first = df.q_TF.apply(lambda x: x[0])
qtf_second = df.q_TF.apply(lambda x: x[1])

# %%
qtf_first.to_csv('qtf_first.csv', index=False)
qtf_second.to_csv('qtf_second.csv', index=False)
