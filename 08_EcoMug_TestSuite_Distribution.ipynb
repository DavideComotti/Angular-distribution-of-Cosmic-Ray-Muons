# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Piano XY

# %%
import numpy as np
import matplotlib.pyplot as plt

# Caricamento dati e conversione in gradi
angles_planeXY = np.loadtxt("angles_planeXY.txt")
GRADI_piano = np.pi - angles_planeXY
GRADI_piano = np.degrees(GRADI_piano)

# ==== FREQUENZE RELATIVE ====

# 1) Costruisco istogramma, ma mi prendo i dati numerici
conteggi, bin_edges = np.histogram(GRADI_piano, bins=150)

# 2) Calcolo le frequenze relative dividendo per il numero totale
totale = len(GRADI_piano)
frequenze_relative = (conteggi / totale) * 100

# 3) Calcolo il valore medio di ogni intervallo di bin per rappresentarlo sull'asse X
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# 4) Grafico frequenza relativa
plt.bar(bin_centers, frequenze_relative, width=(bin_edges[1]-bin_edges[0]))
plt.title('Histogram of the angles from flat-sky generation on a XY-plane')
plt.xlabel('Zenith angle [°]')
plt.ylabel('Relative Frequency [%]')
plt.grid(True)
plt.show()

# %%
# Caricamento dati e conversione in gradi
angles_sphereXY = np.loadtxt("angles_sphereXY.txt")
GRADI_sfera = np.pi - angles_sphereXY
GRADI_sfera = np.degrees(GRADI_sfera)

# ==== FREQUENZE RELATIVE ====

# 1) Costruisco istogramma, ma mi prendo i dati numerici
conteggi, bin_edges = np.histogram(GRADI_sfera, bins=150)

# 2) Calcolo le frequenze relative dividendo per il numero totale
totale = len(GRADI_sfera)
frequenze_relative = (conteggi / totale) *100

# 3) Calcolo il valore medio di ogni intervallo di bin per rappresentarlo sull'asse X
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# 4) Grafico frequenza relativa
plt.bar(bin_centers, frequenze_relative, width=(bin_edges[1]-bin_edges[0]))
plt.title('Histogram of the angles from half-sphere generation on a XY-plane')
plt.xlabel('Zenith angle [°]')
plt.ylabel('Relative Frequency [%]')
plt.grid(True)
plt.show()

# %%
#Piano XZ

# %%
# Caricamento dati e conversione in gradi
angles_planeXZ = np.loadtxt("angles_planeXZ.txt")
GRADI_piano = np.pi - angles_planeXZ
GRADI_piano = np.degrees(GRADI_piano)

# ==== FREQUENZE RELATIVE ====

# 1) Costruisco istogramma, ma mi prendo i dati numerici
conteggi, bin_edges = np.histogram(GRADI_piano, bins=150)

# 2) Calcolo le frequenze relative dividendo per il numero totale
totale = len(GRADI_piano)
frequenze_relative = (conteggi / totale) *100

# 3) Calcolo il valore medio di ogni intervallo di bin per rappresentarlo sull'asse X
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# 4) Grafico frequenza relativa
plt.bar(bin_centers, frequenze_relative, width=(bin_edges[1]-bin_edges[0]))
plt.title('Histogram of the angles from flsy-sky generation on a XZ-plane')
plt.xlabel('Zenith angle [°]')
plt.ylabel('Relative Frequency [%]')
plt.grid(True)
plt.show()

# %%
# Caricamento dati e conversione in gradi
angles_sphereXZ = np.loadtxt("angles_sphereXZ.txt")
GRADI_sfera = np.pi - angles_sphereXZ
GRADI_sfera = np.degrees(GRADI_sfera)

# ==== FREQUENZE RELATIVE ====

# 1) Costruisco istogramma, ma mi prendo i dati numerici
conteggi, bin_edges = np.histogram(GRADI_sfera, bins=150)

# 2) Calcolo le frequenze relative dividendo per il numero totale
totale = len(GRADI_sfera)
frequenze_relative = (conteggi / totale) *100

# 3) Calcolo il valore medio di ogni intervallo di bin per rappresentarlo sull'asse X
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# 4) Grafico frequenza relativa
plt.bar(bin_centers, frequenze_relative, width=(bin_edges[1]-bin_edges[0]))
plt.title('Histogram of the angles from half-sphere generation on a XZ-plane')
plt.xlabel('Zenith angle [°]')
plt.ylabel('Relative Frequency [%]')
plt.grid(True)
plt.show()

# %%
#Piano YZ

# %%
# Caricamento dati e conversione in gradi
angles_planeYZ = np.loadtxt("angles_planeYZ.txt")
GRADI_piano = np.pi - angles_planeYZ
GRADI_piano = np.degrees(GRADI_piano)

# ==== FREQUENZE RELATIVE ====

# 1) Costruisco istogramma, ma mi prendo i dati numerici
conteggi, bin_edges = np.histogram(GRADI_piano, bins=150)

# 2) Calcolo le frequenze relative dividendo per il numero totale
totale = len(GRADI_piano)
frequenze_relative = (conteggi / totale) *100

# 3) Calcolo il valore medio di ogni intervallo di bin per rappresentarlo sull'asse X
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# 4) Grafico frequenza relativa
plt.bar(bin_centers, frequenze_relative, width=(bin_edges[1]-bin_edges[0]))
plt.title('Histogram of the angles from flat-skye generation on a YZ-plane')
plt.xlabel('Zenith angle [°]')
plt.ylabel('Relative Frequency [%]')
plt.grid(True)
plt.show()

# %%
# Caricamento dati e conversione in gradi
angles_sphereYZ = np.loadtxt("angles_sphereYZ.txt")
GRADI_sfera = np.pi - angles_sphereYZ
GRADI_sfera = np.degrees(GRADI_sfera)

# ==== FREQUENZE RELATIVE ====

# 1) Costruisco istogramma, ma mi prendo i dati numerici
conteggi, bin_edges = np.histogram(GRADI_sfera, bins=150)

# 2) Calcolo le frequenze relative dividendo per il numero totale
totale = len(GRADI_sfera)
frequenze_relative = (conteggi / totale) *100

# 3) Calcolo il valore medio di ogni intervallo di bin per rappresentarlo sull'asse X
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# 4) Grafico frequenza relativa
plt.bar(bin_centers, frequenze_relative, width=(bin_edges[1]-bin_edges[0]))
plt.title('Histogram of the angles from half-sphere generation on a YZ-plane')
plt.xlabel('Zenith angle [°]')
plt.ylabel('Relative Frequency [%]')
plt.grid(True)
plt.show()
